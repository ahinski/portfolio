# %% [markdown]
# # Predict Sales

# %% [markdown]
# ## Uploading data

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from matplotlib import pyplot
import seaborn as sns
sns.set_theme(style="darkgrid")

from itertools import product

from datetime import datetime

from keras.models import Sequential
from keras.layers import LSTM,Dense,Dropout,GRU,InputLayer
from keras.optimizers import Adam

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
train = pd.read_csv(r'../input/competitive-data-science-predict-future-sales/sales_train.csv')
test = pd.read_csv(r'../input/competitive-data-science-predict-future-sales/test.csv')
items = pd.read_csv(r'../input/competitive-data-science-predict-future-sales/items.csv')
item_categories = pd.read_csv(r'../input/competitive-data-science-predict-future-sales/item_categories.csv')
shops = pd.read_csv(r'../input/competitive-data-science-predict-future-sales/shops.csv')

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
train['date'] = pd.to_datetime(train['date'])

# %%
train['dayofweek'] = train['date'].dt.dayofweek

train = train.join(items, on='item_id', rsuffix='_pr')
train.drop(columns=['item_id_pr'], inplace=True)

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
item_categories.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %% [markdown]
# ## Exploratory Analysis and Data Cleaning

# %%
print('Amount of items: ' + str(items.shape))
print('Amount of shops: ' + str(shops.shape))
print('Amount of categories: ' + str(item_categories.shape))
# Out:
# Amount of items: (22170, 3)
# Amount of shops: (60, 2)
# Amount of categories: (84, 2)

# %%
len(test['shop_id'].unique())
# Out:
# 42

# %%
test['shop_id'].unique()
# Out:
# array([ 5,  4,  6,  3,  2,  7, 10, 12, 28, 31, 26, 25, 22, 24, 21, 15, 16,
#        18, 14, 19, 42, 50, 49, 53, 52, 47, 48, 57, 58, 59, 55, 56, 36, 37,
#        35, 38, 34, 46, 41, 44, 39, 45])

# %%
len(test['item_id'].unique())
# Out:
# 5100

# %% [markdown]
# Not every shop's and item's sales must be forecasted.

# %%
train.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day  \
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03
#
#           dayofweek  item_category_id
# count  2.935849e+06      2.935849e+06
# mean   3.235982e+00      4.000138e+01
# std    2.009566e+00      1.710076e+01
# min    0.000000e+00      0.000000e+00
# 25%    1.000000e+00      2.800000e+01
# 50%    3.000000e+00      4.000000e+01
# 75%    5.000000e+00      5.500000e+01
# max    6.000000e+00      8.300000e+01

# %% [markdown]
# **There are negative item_price and item_cnt_day**

# %%
train[train['item_price'] < 0]
# Out:
#              date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 484683 2013-05-15               4       32     2973        -1.0           1.0
#
#         dayofweek                                  item_name  item_category_id
# 484683          2  DmC Devil May Cry [PS3, русские субтитры]                19

# %% [markdown]
# Replacing it's with mean price for this item

# %%
train.at[484683, 'item_price'] = train.loc[train['item_id'] == 2973, 'item_price'].mean()

# %%
train[train['item_cnt_day'] < 0].shape
# Out:
# (7356, 9)

# %% [markdown]
# Replacing 'item_cnt_day' < 0 with 0

# %%
train.loc[train['item_cnt_day'] < 0, 'item_cnt_day'] = 0

# %%
train.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day  \
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908539e+02  1.245209e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.617046e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00  7.000000e-02  0.000000e+00
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03
#
#           dayofweek  item_category_id
# count  2.935849e+06      2.935849e+06
# mean   3.235982e+00      4.000138e+01
# std    2.009566e+00      1.710076e+01
# min    0.000000e+00      0.000000e+00
# 25%    1.000000e+00      2.800000e+01
# 50%    3.000000e+00      4.000000e+01
# 75%    5.000000e+00      5.500000e+01
# max    6.000000e+00      8.300000e+01

# %% [markdown]
# **We'll handle outliers differently for different approaches**

# %% [markdown]
# **Handling duplicates**

# %%
train[train.duplicated() == True]
# Out:
#               date  date_block_num  shop_id  item_id  item_price  \
# 76962   2013-05-01               0       54    20130       149.0
# 1435367 2014-02-23              13       50     3423       999.0
# 1496766 2014-03-23              14       21     3423       999.0
# 1671873 2014-01-05              16       50     3423       999.0
# 1866340 2014-12-07              18       25     3423       999.0
# 2198566 2014-12-31              23       42    21619       499.0
#
#          item_cnt_day  dayofweek  \
# 76962             1.0          2
# 1435367           1.0          6
# 1496766           1.0          6
# 1671873           1.0          6
# 1866340           1.0          6
# 2198566           1.0          2
#
#                                                item_name  item_category_id
# 76962                            УЧЕНИК ЧАРОДЕЯ (регион)                40
# 1435367  Far Cry 3 (Classics) [Xbox 360, русская версия]                23
# 1496766  Far Cry 3 (Classics) [Xbox 360, русская версия]                23
# 1671873  Far Cry 3 (Classics) [Xbox 360, русская версия]                23
# 1866340  Far Cry 3 (Classics) [Xbox 360, русская версия]                23
# 2198566                               ЧЕЛОВЕК ДОЖДЯ (BD)                37

# %%
train.drop(train[train.duplicated() == True].index, inplace=True)

# %% [markdown]
# ### Sales graphs

# %%
shop_items_day = train.groupby(['shop_id', 'date']).sum().sort_values(by=['date'])
shop_items_month = train.groupby(['shop_id', 'date_block_num']).sum().sort_values(by=['date_block_num'])

# %% [markdown]
# #### Sales graph for company

# %%
comp_items_month = train.groupby(['date_block_num']).agg({'item_cnt_day': 'sum'})

# %%
comp_items_day = train.groupby(['date']).agg({'item_cnt_day': 'sum'})
comp_items_day['dayofweek'] = comp_items_day.index.get_level_values('date').dayofweek
comp_items_day['month'] = comp_items_day.index.get_level_values('date').month

# %% [markdown]
# **By day**

# %%
fig, ax = pyplot.subplots(figsize=(20, 10))
sns.lineplot(ax = ax, x='date', y='item_cnt_day',
             data=comp_items_day.sort_values(by=['date']))
# Out:
# <AxesSubplot:xlabel='date', ylabel='item_cnt_day'>

# %% [markdown]
# **By month**

# %%
fig, ax = pyplot.subplots(figsize=(20, 10))
sns.lineplot(ax = ax, x='date_block_num', y='item_cnt_day',
             data=comp_items_month.sort_values(by=['date_block_num']))
# Out:
# <AxesSubplot:xlabel='date_block_num', ylabel='item_cnt_day'>

# %% [markdown]
# **By day of week**

# %%
fig, ax = pyplot.subplots(figsize=(20, 10))
sns.lineplot(ax = ax, x='dayofweek', y='item_cnt_day',
             data=comp_items_day.sort_values(by=['date']))
# Out:
# <AxesSubplot:xlabel='dayofweek', ylabel='item_cnt_day'>

# %% [markdown]
# **By number of month**

# %%
fig, ax = pyplot.subplots(figsize=(20, 10))
sns.lineplot(ax = ax, x='month', y='item_cnt_day',
             data=comp_items_day.sort_values(by=['date']))
# Out:
# <AxesSubplot:xlabel='month', ylabel='item_cnt_day'>

# %% [markdown]
# **There is a trend of sales decreasing through time and seasonality (boom in the end of the year). Also there's a weekly seasonality**

# %%
g = sns.FacetGrid(shop_items_month.reset_index(), col='shop_id', height=2, col_wrap=5)
g.map(sns.lineplot, 'date_block_num', 'item_cnt_day')

# %% [markdown]
# **All representive shops (without information being interrupted) seems to confirm the seasonality and trend of decreasing, except for shop 55 and 12**

# %%
shops[shops['shop_id'] == 12]
# Out:
#               shop_name  shop_id
# 12  Интернет-магазин ЧС       12

# %%
fig, ax = pyplot.subplots(figsize=(15, 10))
ax.xaxis_date()
fig.autofmt_xdate()
sns.lineplot(ax = ax, x='date', y='item_cnt_day',
             data=shop_items_day[shop_items_day.index.get_level_values('shop_id') == 12].sort_values(by=['date']))
# Out:
# <AxesSubplot:xlabel='date', ylabel='item_cnt_day'>

# %%
shops[shops['shop_id'] == 55]
# Out:
#                    shop_name  shop_id
# 55  Цифровой склад 1С-Онлайн       55

# %%
fig, ax = pyplot.subplots(figsize=(15, 10))
ax.xaxis_date()
fig.autofmt_xdate()
sns.lineplot(ax = ax, x='date', y='item_cnt_day',
             data=shop_items_day[shop_items_day.index.get_level_values('shop_id') == 55].sort_values(by=['date']))
# Out:
# <AxesSubplot:xlabel='date', ylabel='item_cnt_day'>

# %% [markdown]
# **Both shops are online (the last one is a warehouse) so that can explain their deviation.**

# %% [markdown]
# #### Sales graphs for categories

# %%
items['item_category_id'].value_counts()
# Out:
# 40    5035
# 55    2365
# 37    1780
# 31    1125
# 58     790
#       ...
# 50       2
# 1        2
# 10       1
# 51       1
# 79       1
# Name: item_category_id, Length: 84, dtype: int64

# %%
categories_items_day = train.groupby(['item_category_id', 'date']).sum()
categories_items_month = train.groupby(['item_category_id', 'date_block_num']).sum()

# %%
fig, ax = pyplot.subplots(figsize=(20, 10))
pyplot.xticks(rotation=45)
sns.barplot(ax=ax, x=items['item_category_id'].value_counts().index, y=items['item_category_id'].value_counts())
# Out:
# <AxesSubplot:ylabel='item_category_id'>

# %%
g = sns.FacetGrid(categories_items_month.reset_index().sort_values(by=['date_block_num']),
                  col='item_category_id', height=2, col_wrap=5)
g.map(sns.lineplot, 'date_block_num', 'item_cnt_day')

# %% [markdown]
# **Most of categories are not represented widely, but seem to repeat general seasonality.
# However, some of the most popular categories (id=40 and 30) seem to have a trend of decreasing, but the seasonality (if it actually exist) doesn't repeat common for all items**

# %%
item_categories.iloc[30]
# Out:
# item_category_name    Игры PC - Стандартные издания
# item_category_id                                 30
# Name: 30, dtype: object

# %%
item_categories.iloc[40]
# Out:
# item_category_name    Кино - DVD
# item_category_id              40
# Name: 40, dtype: object

# %% [markdown]
# **These two categories are 'PC Games' and 'DVD Movies'. So we can suggest that spikes in sales we see are due to the release of a new game or movie.**

# %% [markdown]
# ### Dependence of price on sales

# %%
items_day = train.groupby(['item_id', 'date']).agg({'item_price':'mean', 'item_cnt_day': 'sum'})
items_month = train.groupby(['item_id', 'date_block_num']).agg({'item_price':'mean', 'item_cnt_day': 'sum'})
items_count = train.groupby(['item_id']).sum()['item_cnt_day']

# %%
top_items_count= items_count.sort_values(ascending=False).index[:20]

# %%
top_items_month = items_month[np.isin(items_month.index.get_level_values('item_id'), top_items_count)]

# %%
g = sns.FacetGrid(top_items_month.reset_index().sort_values(by=['date_block_num']),
                  col='item_id', height=2, col_wrap=5, sharey=False, sharex=True)
g.map(sns.lineplot, 'date_block_num', 'item_cnt_day', color = 'red', label='counts')
g.map(sns.lineplot, 'date_block_num', 'item_price', label='price')
g.add_legend()

# %%
print(items[items['item_id'] == 1830]['item_name'])
print(items[items['item_id'] == 2308]['item_name'])
print(items[items['item_id'] == 11373]['item_name'])
print(items[items['item_id'] == 20949]['item_name'])
print(items[items['item_id'] == 5822]['item_name'])
print(items[items['item_id'] == 17717]['item_name'])
# Out:
# 1830    Battlefield 3 [PC, Jewel, русская версия]
# Name: item_name, dtype: object
# 2308    Call of Duty: Black Ops II [PС, Jewel, русская...
# Name: item_name, dtype: object
# 11373    Доставка до пункта выдачи (Boxberry)
# Name: item_name, dtype: object
# 20949    Фирменный пакет майка 1С Интерес белый (34*42)...
# Name: item_name, dtype: object
# 5822    Playstation Store пополнение бумажника: Карта ...
# Name: item_name, dtype: object
# 17717    Прием денежных средств для 1С-Онлайн
# Name: item_name, dtype: object

# %% [markdown]
# **There is no visible correlation of price with sales.**

# %%
fig, ax = pyplot.subplots(figsize=(10, 10))
sns.heatmap(train.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## LSTM / GRU approach

# %% [markdown]
# ### Outliers  handing

# %%
train['item_cnt_day'].describe()
# Out:
# count    2.935843e+06
# mean     1.245210e+00
# std      2.617049e+00
# min      0.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      2.169000e+03
# Name: item_cnt_day, dtype: float64

# %%
train['item_cnt_day'] = train['item_cnt_day'].astype('float32')

# %%
sns.displot(x=train['item_cnt_day'], kind='kde')

# %%
train.loc[train['item_cnt_day'] > 20, 'item_cnt_day'] = 20

# %%
sns.displot(x=train['item_cnt_day'], kind='kde')

# %% [markdown]
# **We'll use the last 12 months before the target and validation set to tune hyperparameters**

# %%
NN_train = train[train['date_block_num'] > 20].groupby(['item_id', 'shop_id',
                                                          'date_block_num']).agg({'item_cnt_day': 
                                                                                  'sum'}).sort_values(by='date_block_num')
NN_train_tune = train[train['date_block_num'] > 19].groupby(['item_id', 'shop_id',
                                                          'date_block_num']).agg({'item_cnt_day': 
                                                                                  'sum'}).sort_values(by='date_block_num')

# %%
NN_train.reset_index(inplace=True)
NN_train_tune.reset_index(inplace=True)

# %%
sns.displot(x=NN_train['item_cnt_day'], kind='kde')
sns.displot(x=NN_train_tune['item_cnt_day'], kind='kde')

# %%
NN_train = NN_train.pivot_table(index=['item_id', 'shop_id'], columns=['date_block_num'], values=['item_cnt_day'])
NN_train_tune = NN_train_tune.pivot_table(index=['item_id', 'shop_id'], columns=['date_block_num'], values=['item_cnt_day'])

# %%
NN_train.reset_index(inplace=True)
NN_train_tune.reset_index(inplace=True)

# %%
NN_train = pd.merge(test, NN_train, on=['item_id', 'shop_id'], how='left')
NN_train_tune = pd.merge(test, NN_train_tune, on=['item_id', 'shop_id'], how='left')
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/merge.py:648: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
print(NN_train.shape)
print(NN_train_tune.shape)
print(test.shape)
# Out:
# (214200, 16)
# (214200, 17)
# (214200, 3)

# %% [markdown]
# ### Missing values

# %%
NN_train.fillna(0, inplace=True)
NN_train_tune.fillna(0, inplace=True)

# %% [markdown]
# ### Building a model

# %% [markdown]
# **Training on 32th month, validate on 33th. After tuning use X_valid and Y_valid to train our model to predict 34th month**

# %%
X_train = NN_train_tune.iloc[:, 3:-2].values.reshape(214200, 12, 1)
Y_train = NN_train_tune.iloc[:, -2:-1].values.reshape(214200, 1)

X_valid = NN_train.iloc[:, 3:-1].values.reshape(214200, 12, 1)
Y_valid = NN_train.iloc[:, -1:].values.reshape(214200, 1)

X_test = NN_train.iloc[:, 4:].values.reshape(214200, 12, 1)

# %%
print(X_train.shape, Y_train.shape)
print(X_valid.shape, Y_valid.shape)
print(X_test.shape)
# Out:
# (214200, 12, 1) (214200, 1)
# (214200, 12, 1) (214200, 1)
# (214200, 12, 1)

# %% [markdown]
# #### LSTM

# %%
def create_LSTM():
    LSTM_model = Sequential()
    LSTM_model.add(LSTM(units = 32, input_shape=(12,1)))
    LSTM_model.add(Dropout(0.3))
    LSTM_model.add(Dense(1, activation='linear'))
    LSTM_model.compile(loss = 'mse',optimizer = 'adam', metrics = ['accuracy'])
    LSTM_model.summary()
    return LSTM_model

# %%
tune_LSTM = create_LSTM()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 32)                4352
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tune_LSTM.fit(X_train,Y_train, batch_size=4000, epochs = 50, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1
# 54/54 [==============================] - 5s 93ms/step - loss: 3.0736 - accuracy: 0.8577 - val_loss: 4.0734 - val_accuracy: 0.8503
# Epoch 42/50
# 54/54 [==============================] - 5s 94ms/step - loss: 2.7729 - accuracy: 0.8587 - val_loss: 4.0618 - val_accuracy: 0.8450
# Epoch 43/50
# 54/54 [==============================] - 5s 95ms/step - loss: 3.9686 - accuracy: 0.8542 - val_loss: 4.0441 - val_accuracy: 0.8498
# Epoch 44/50
# 54/54 [==============================] - 5s 96ms/step - loss: 4.8200 - accuracy: 0.8579 - val_loss: 4.0325 - val_accuracy: 0.8514
# Epoch 45/50
# 54/54 [==============================] - 5s 93ms/step - loss: 2.8033 - accuracy: 0.8580 - val_loss: 4.0218 - val_accuracy: 0.8532
# Epoch 46/50
# 54/54 [==============================] - 5s 92ms/step - loss: 4.3050 - accuracy: 0.8589 - val_loss: 4.0119 - val_accuracy: 0.8502
# Epoch 47/50
# 54/54 [==============================] - 5s 93ms/step - loss: 4.5719 - accuracy: 0.8563 - val_loss: 4.0085 - val_accuracy: 0.8535
# Epoch 48/50
# 54/54 [==============================] - 5s 92ms/step - loss: 3.3983 - accuracy: 0.8565 - val_loss: 3.9885 - val_accuracy: 0.8513
# Epoch 49/50
# 54/54 [==============================] - 5s 93ms/step - loss: 5.4844 - accuracy: 0.8581 - val_loss: 3.9719 - val_accuracy: 0.8497
# Epoch 50/50
# 54/54 [==============================] - 5s 96ms/step - loss: 3.0412 - accuracy: 0.8571 - val_loss: 3.9727 - val_accuracy: 0.8508

# %%
sns.lineplot(data = history.history['loss'], label='loss')
sns.lineplot(data = history.history['val_loss'], label='val_loss')
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data = history.history['accuracy'], label='accuracy')
sns.lineplot(data = history.history['val_accuracy'], label='val_accuracy')
# Out:
# <AxesSubplot:>

# %%
print('LMST')
print('mse - ' + str(min(history.history['val_loss'])))
print('acc - ' + str(min(history.history['val_accuracy'])))
# Out:
# LMST
# mse - 3.971933603286743
# acc - 0.84498131275177

# %%
LSTM_model = create_LSTM()
history = LSTM_model.fit(X_valid, Y_valid, batch_size=4000, epochs = 50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 32)                4352
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 54/54 [==============================] - 5s 65ms/step - loss: 5.9351 - accuracy: 0.8571
# Epoch 2/50
# 54/54 [==============================] - 3s 65ms/step - loss: 4.0877 - accuracy: 0.8475
# Epoch 3/50
# 54/54 [==============================] - 3s 64ms/step - loss: 4.7291 - accuracy: 0.8488
# Epoch 4/50
# 54/54 [==============================] - 4s 66ms/step - loss: 5.5703 - accuracy: 0.8487
# Epoch 5/50
# 54/54 [==============================] - 3s 65ms/step - loss: 7.0307 - accuracy: 0.8496
# Epoch 6/50
# 54/54 [==============================] - 3s 64ms/step - loss: 4.3038 - accuracy: 0.8498
# Epoch 7/50
# 54/54 [==============================] - 4s 65ms/step - loss: 3.1186 - accuracy: 0.8511
# Epoch 8/50
# Epoch 37/50
# 54/54 [==============================] - 3s 65ms/step - loss: 4.4514 - accuracy: 0.8517
# Epoch 38/50
# 54/54 [==============================] - 4s 66ms/step - loss: 2.4408 - accuracy: 0.8490
# Epoch 39/50
# 54/54 [==============================] - 4s 65ms/step - loss: 3.7798 - accuracy: 0.8515
# Epoch 40/50
# 54/54 [==============================] - 4s 68ms/step - loss: 4.2240 - accuracy: 0.8484
# Epoch 41/50
# 54/54 [==============================] - 4s 71ms/step - loss: 3.3096 - accuracy: 0.8491
# Epoch 42/50
# 54/54 [==============================] - 4s 68ms/step - loss: 5.7998 - accuracy: 0.8473
# Epoch 43/50
# 54/54 [==============================] - 4s 65ms/step - loss: 4.0443 - accuracy: 0.8485
# Epoch 44/50
# 54/54 [==============================] - 4s 66ms/step - loss: 2.6613 - accuracy: 0.8495
# Epoch 45/50
# 54/54 [==============================] - 4s 70ms/step - loss: 2.3050 - accuracy: 0.8493
# Epoch 46/50
# 54/54 [==============================] - 4s 67ms/step - loss: 6.2375 - accuracy: 0.8491
# Epoch 47/50
# 54/54 [==============================] - 4s 65ms/step - loss: 3.4410 - accuracy: 0.8495
# Epoch 48/50
# 54/54 [==============================] - 3s 64ms/step - loss: 3.4401 - accuracy: 0.8493
# Epoch 49/50
# 54/54 [==============================] - 3s 64ms/step - loss: 5.4851 - accuracy: 0.8475
# Epoch 50/50
# 54/54 [==============================] - 4s 65ms/step - loss: 4.0429 - accuracy: 0.8474

# %%
sns.lineplot(data = history.history['loss'], label='loss')
# Out:
# <AxesSubplot:>

# %%
LSTM_y = LSTM_model.predict(X_test)

# %% [markdown]
# #### GRU

# %%
def create_GRU():
    GRU_model = Sequential()
    GRU_model.add(GRU(units = 32, input_shape=(12,1)))
    GRU_model.add(Dropout(0.3))
    GRU_model.add(Dense(1, activation='relu'))
    GRU_model.compile(loss = 'mse',optimizer = 'adam', metrics = ['accuracy'])
    GRU_model.summary()
    return GRU_model

# %%
GRU_tune = create_GRU()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 32)                3360
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 3,393
# Trainable params: 3,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_GRU = GRU_tune.fit(X_train, Y_train, batch_size=4000, epochs = 60, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/60
# 54/54 [==============================] - 7s 96ms/step - loss: 5.3719 - accuracy: 0.8672 - val_loss: 5.1722 - val_accuracy: 0.8361
# Epoch 2/60
# 54/54 [==============================] - 5s 89ms/step - loss: 4.0463 - accuracy: 0.8483 - val_loss: 5.0608 - val_accuracy: 0.8378
# Epoch 3/60
# 54/54 [==============================] - 5s 88ms/step - loss: 4.7508 - accuracy: 0.8487 - val_loss: 4.9508 - val_accuracy: 0.8423
# Epoch 4/60
# 54/54 [==============================] - 5s 88ms/step - loss: 2.5202 - accuracy: 0.8511 - val_loss: 4.8804 - val_accuracy: 0.8452
# Epoch 5/60
60
# 54/54 [==============================] - 5s 87ms/step - loss: 3.0960 - accuracy: 0.8583 - val_loss: 4.0328 - val_accuracy: 0.8519
# Epoch 48/60
# 54/54 [==============================] - 5s 85ms/step - loss: 2.8633 - accuracy: 0.8580 - val_loss: 4.0183 - val_accuracy: 0.8485
# Epoch 49/60
# 54/54 [==============================] - 5s 90ms/step - loss: 2.6676 - accuracy: 0.8567 - val_loss: 4.0030 - val_accuracy: 0.8513
# Epoch 50/60
# 54/54 [==============================] - 5s 87ms/step - loss: 3.8669 - accuracy: 0.8561 - val_loss: 4.0079 - val_accuracy: 0.8534
# Epoch 51/60
# 54/54 [==============================] - 5s 87ms/step - loss: 3.1390 - accuracy: 0.8544 - val_loss: 3.9903 - val_accuracy: 0.8564
# Epoch 52/60
# 54/54 [==============================] - 5s 87ms/step - loss: 5.4525 - accuracy: 0.8577 - val_loss: 3.9615 - val_accuracy: 0.8508
# Epoch 53/60
# 54/54 [==============================] - 5s 88ms/step - loss: 3.5576 - accuracy: 0.8550 - val_loss: 3.9518 - val_accuracy: 0.8521
# Epoch 54/60
# 54/54 [==============================] - 5s 87ms/step - loss: 3.2803 - accuracy: 0.8571 - val_loss: 3.9453 - val_accuracy: 0.8544
# Epoch 55/60
# 54/54 [==============================] - 5s 89ms/step - loss: 4.2933 - accuracy: 0.8542 - val_loss: 3.9524 - val_accuracy: 0.8536
# Epoch 56/60
# 54/54 [==============================] - 5s 98ms/step - loss: 3.8459 - accuracy: 0.8575 - val_loss: 3.9167 - val_accuracy: 0.8507
# Epoch 57/60
# 54/54 [==============================] - 5s 89ms/step - loss: 5.0901 - accuracy: 0.8566 - val_loss: 3.9279 - val_accuracy: 0.8535
# Epoch 58/60
# 54/54 [==============================] - 5s 88ms/step - loss: 3.1247 - accuracy: 0.8581 - val_loss: 3.9016 - val_accuracy: 0.8520
# Epoch 59/60
# 54/54 [==============================] - 5s 87ms/step - loss: 3.9926 - accuracy: 0.8547 - val_loss: 3.8859 - val_accuracy: 0.8533
# Epoch 60/60
# 54/54 [==============================] - 5s 88ms/step - loss: 2.6397 - accuracy: 0.8561 - val_loss: 3.8863 - val_accuracy: 0.8495

# %%
sns.lineplot(data = history_GRU.history['loss'], label='loss')
sns.lineplot(data = history_GRU.history['val_loss'], label='val_loss')
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data = history_GRU.history['accuracy'], label='accuracy')
sns.lineplot(data = history_GRU.history['val_accuracy'], label='val_accuracy')
# Out:
# <AxesSubplot:>

# %%
print('GRU')
print('mse - ' + str(min(history_GRU.history['val_loss'])))
print('acc - ' + str(min(history_GRU.history['val_accuracy'])))
# Out:
# GRU
# mse - 3.885909080505371
# acc - 0.8360643982887268

# %%
GRU_model = create_GRU()
history_GRU = GRU_model.fit(X_valid, Y_valid, batch_size=4000, epochs = 60)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 32)                3360
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 3,393
# Trainable params: 3,393
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 54/54 [==============================] - 5s 61ms/step - loss: 6.1713 - accuracy: 0.8580
# Epoch 2/60
# 54/54 [==============================] - 4s 66ms/step - loss: 4.8790 - accuracy: 0.8356
# Epoch 3/60
# 54/54 [==============================] - 3s 61ms/step - loss: 5.0196 - accuracy: 0.8382
# Epoch 4/60
# 54/54 [==============================] - 3s 61ms/step - loss: 3
60
# 54/54 [==============================] - 3s 61ms/step - loss: 4.7878 - accuracy: 0.8467
# Epoch 37/60
# 54/54 [==============================] - 3s 61ms/step - loss: 2.5915 - accuracy: 0.8487
# Epoch 38/60
# 54/54 [==============================] - 3s 61ms/step - loss: 3.4668 - accuracy: 0.8490
# Epoch 39/60
# 54/54 [==============================] - 3s 62ms/step - loss: 3.0048 - accuracy: 0.8473
# Epoch 40/60
# 54/54 [==============================] - 3s 61ms/step - loss: 2.4514 - accuracy: 0.8479
# Epoch 41/60
# 54/54 [==============================] - 3s 61ms/step - loss: 5.6213 - accuracy: 0.8463
# Epoch 42/60
# 54/54 [==============================] - 4s 66ms/step - loss: 6.0207 - accuracy: 0.8480
# Epoch 43/60
# 54/54 [==============================] - 3s 62ms/step - loss: 3.0782 - accuracy: 0.8456
# Epoch 44/60
# 54/54 [==============================] - 3s 62ms/step - loss: 3.5636 - accuracy: 0.8485
# Epoch 45/60
# 54/54 [==============================] - 3s 61ms/step - loss: 4.0627 - accuracy: 0.8436
# Epoch 46/60
# 54/54 [==============================] - 3s 61ms/step - loss: 4.1105 - accuracy: 0.8483
# Epoch 47/60
# 54/54 [==============================] - 3s 62ms/step - loss: 2.5160 - accuracy: 0.8481
# Epoch 48/60
# 54/54 [==============================] - 3s 63ms/step - loss: 3.3354 - accuracy: 0.8458
# Epoch 49/60
# 54/54 [==============================] - 3s 64ms/step - loss: 2.3038 - accuracy: 0.8438
# Epoch 50/60
# 54/54 [==============================] - 3s 62ms/step - loss: 4.5341 - accuracy: 0.8468
# Epoch 51/60
# 54/54 [==============================] - 3s 61ms/step - loss: 4.9994 - accuracy: 0.8475
# Epoch 52/60
# 54/54 [==============================] - 3s 62ms/step - loss: 4.4157 - accuracy: 0.8479
# Epoch 53/60
# 54/54 [==============================] - 3s 61ms/step - loss: 4.2972 - accuracy: 0.8467
# Epoch 54/60
# 54/54 [==============================] - 3s 61ms/step - loss: 3.2748 - accuracy: 0.8438
# Epoch 55/60
# 54/54 [==============================] - 3s 62ms/step - loss: 4.0676 - accuracy: 0.8477
# Epoch 56/60
# 54/54 [==============================] - 3s 64ms/step - loss: 2.7823 - accuracy: 0.8468
# Epoch 57/60
# 54/54 [==============================] - 3s 61ms/step - loss: 4.2274 - accuracy: 0.8452
# Epoch 58/60
# 54/54 [==============================] - 3s 61ms/step - loss: 3.6455 - accuracy: 0.8458
# Epoch 59/60
# 54/54 [==============================] - 3s 61ms/step - loss: 5.0042 - accuracy: 0.8475
# Epoch 60/60
# 54/54 [==============================] - 3s 61ms/step - loss: 4.6689 - accuracy: 0.8452

# %%
sns.lineplot(data = history_GRU.history['loss'], label='loss')
# Out:
# <AxesSubplot:>

# %%
GRU_y = GRU_model.predict(X_test)

# %%
LSTM_y = LSTM_y.reshape(214200)
GRU_y = GRU_y.reshape(214200)

# %%
del X_train
del X_valid
del Y_train
del Y_valid
del X_test

LSTM_y = LSTM_y.reshape(214200)
GRU_y = GRU_y.reshape(214200)

# %% [markdown]
# ## Feuture engineering and Light GBM approach

# %% [markdown]
# ### Categories

# %%
new_train = train.groupby(['date_block_num', 'item_id', 'shop_id']).agg({'item_cnt_day': 'sum',
                                                                         'item_category_id':'first'})
new_train.reset_index(inplace=True)

# %%
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in range(34):
    sales = train[train.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))
    
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix['item_id'] = matrix['item_id'].astype(np.int16)
matrix.sort_values(cols,inplace=True)

# %%
new_train = pd.merge(matrix, new_train, on=['date_block_num', 'item_id', 'shop_id'], how='left')
del matrix

# %%
new_train['item_cnt_day'].fillna(0, inplace=True)

# %%
new_train = new_train.join(items[['item_id', 'item_category_id']], on='item_id', 
                           how='left', lsuffix='_out').drop(columns=['item_id_out', 'item_category_id_out'])

# %% [markdown]
# Distribution plot for whole 'item_cnt_day' column

# %%
sns.displot(x=new_train['item_cnt_day'], kind='kde')

# %% [markdown]
# Distribution plot for 33th month

# %%
sns.displot(x=new_train.loc[new_train['date_block_num'] == 33, 'item_cnt_day'], kind='kde')

# %% [markdown]
# **GBM is sensitive to outliers, so we'll counts to (0,20)**

# %%
new_train['item_cnt_day'] = np.clip(new_train['item_cnt_day'], 0, 20)

# %% [markdown]
# **We'll unite common categories like music(Музыка), presents(Подарки) etc.**

# %%
print(item_categories['item_category_name'].to_string())
# Out:
# 0                      PC - Гарнитуры/Наушники
# 1                             Аксессуары - PS2
# 2                             Аксессуары - PS3
# 3                             Аксессуары - PS4
# 4                             Аксессуары - PSP
# 5                          Аксессуары - PSVita
# 6                        Аксессуары - XBOX 360
# 7                        Аксессуары - XBOX ONE
# 8                               Билеты (Цифра)
# 9                              Доставка товара
# 10                       Игровые консоли - PS2
# 11                       Игровые консоли - PS3
# 12                       Игровые консоли - PS4
# 13                       Игровые консоли - PSP
# 14                    Игровые консоли - PSVita
# 15                  Игровые консоли - XBOX 360
# 16                  Игровые консоли - XBOX ONE
# 17                    Игровые консоли - Прочие
# 18                                  Игры - PS2
# 19                                  Игры - PS3
# 20                                  Игры - PS4
# 21                                  Игры - PSP
# 22                               Игры - PSVita
# 23                             Игры - XBOX 360
# 24                             Игры - XBOX ONE
# 25                   Игры - Аксессуары для игр
# 26                        Игры Android - Цифра
# 27                            Игры MAC - Цифра
# 28            Игры PC - Дополнительные издания
# 29             Игры PC - Коллекционные издания
# 30               Игры PC - Стандартные издания
# 31                             Игры PC - Цифра
# 32           Карты оплаты (Кино, Музыка, Игры)
# 33                        Карты оплаты - Live!
# 34                Карты оплаты - Live! (Цифра)
# 35                          Карты оплаты - PSN
# 36              Карты оплаты - Windows (Цифра)
# 37                              Кино - Blu-Ray
# 38                           Кино - Blu-Ray 3D
# 39                           Кино - Blu-Ray 4K
# 40                                  Кино - DVD
# 41                        Кино - Коллекционное
# 42               Книги - Артбуки, энциклопедии
# 43                          Книги - Аудиокниги
# 44                  Книги - Аудиокниги (Цифра)
# 45                       Книги - Аудиокниги 1С
# 46                   Книги - Бизнес литература
# 47                      Книги - Комиксы, манга
# 48             Книги - Компьютерная литература
# 49           Книги - Методические материалы 1С
# 50                            Книги - Открытки
# 51           Книги - Познавательная литература
# 52                        Книги - Путеводители
# 53           Книги - Художественная литература
# 54                               Книги - Цифра
# 55         Музыка - CD локального производства
# 56         Музыка - CD фирменного производства
# 57                                Музыка - MP3
# 58                              Музыка - Винил
# 59                  Музыка - Музыкальное видео
# 60                 Музыка - Подарочные издания
# 61                        Подарки - Атрибутика
# 62            Подарки - Гаджеты, роботы, спорт
# 63                    Подарки - Мягкие игрушки
# 64                   Подарки - Настольные игры
# 65      Подарки - Настольные игры (компактные)
# 66                Подарки - Открытки, наклейки
# 67                          Подарки - Развитие
# 68               Подарки - Сертификаты, услуги
# 69                          Подарки - Сувениры
# 70              Подарки - Сувениры (в навеску)
# 71    Подарки - Сумки, Альбомы, Коврики д/мыши
# 72                           Подарки - Фигурки
# 73                Программы - 1С:Предприятие 8
# 74                     Программы - MAC (Цифра)
# 75                Программы - Для дома и офиса
# 76        Программы - Для дома и офиса (Цифра)
# 77                       Программы - Обучающие
# 78               Программы - Обучающие (Цифра)
# 79                                   Служебные
# 80                          Служебные - Билеты
# 81                     Чистые носители (шпиль)
# 82                   Чистые носители (штучные)
# 83                            Элементы питания

# %%
categories = {'Accessories':[i for i in range(0,8)], 'Consoles':[i for i in range(10,18)],
             'Games':[i for i in range(18,32)], 'Pay cards':[i for i in range(32,37)],
             'Movie':[i for i in range(32,42)], 'Books':[i for i in range(42,55)],
              'Music':[i for i in range(55,61)], 'Presents':[i for i in range(61,73)],
             'Programmes':[i for i in range(73,79)], 'Others':[8,9,79,80,81,82,83]
             }

# %%
test = test.join(item_categories, on='item_id', how='left')
test['item_category_id'].value_counts(dropna=False)
# Out:
# NaN     213360
# 64.0        42
# 57.0        42
# 70.0        42
# 30.0        42
# 59.0        42
# 76.0        42
# 67.0        42
# 51.0        42
# 53.0        42
# 80.0        42
# 62.0        42
# 83.0        42
# 69.0        42
# 45.0        42
# 38.0        42
# 31.0        42
# 33.0        42
# 72.0        42
# 42.0        42
# 32.0        42
# Name: item_category_id, dtype: int64

# %%
#ALL nans go to Others category
test['item_category_id'].fillna(83, inplace=True)

# %%
for key in categories:
    new_train.loc[np.isin(new_train['item_category_id'], categories[key]), 'category'] = key
    test.loc[np.isin(test['item_category_id'], categories[key]), 'category'] = key

# %% [markdown]
# ### Date features

# %%
new_train['month'] = new_train['date_block_num'] % 12
new_train['year'] = new_train['date_block_num'] // 12
test['month'] = 10
test['year'] = 2
test['date_block_num'] = 34

# %% [markdown]
# ### Shop features

# %%
new_train = new_train.join(shops, on='shop_id', how='left', rsuffix='_shp')
test = test.join(shops, on='shop_id', how='left', rsuffix='_shp')

# %%
new_train['shop_city'] = new_train['shop_name'].str.split().str[0]
test['shop_city'] = test['shop_name'].str.split().str[0]

# %%
new_train.drop(columns = ['item_category_id', 'shop_name', 'shop_id_shp'], inplace=True)
test.drop(columns = ['ID', 'item_category_name', 'item_category_id', 'shop_name', 'shop_id_shp'], inplace=True)

# %%
new_train['date_block_num'] = new_train['date_block_num'].astype('int16')
new_train['shop_id'] = new_train['shop_id'].astype('int16')
new_train['item_id'] = new_train['item_id'].astype('int16')
new_train['year'] = new_train['year'].astype('int16')
new_train['month'] = new_train['month'].astype('int16')

# %% [markdown]
# ### Lag features

# %% [markdown]
# **We'll create lags for 1-6, 8, 10, 12 months**

# %%
NUMBERS = [1,2,3,4,5,6,12]

def create_lag(data, test, col, numbers):
    for lag in numbers:
        tmp = data[['date_block_num', 'item_id', 'shop_id', col]].copy()
        tmp['date_block_num'] = tmp['date_block_num'].apply(lambda x: x+lag)
        tmp[col + '_lag_' + str(lag)] = tmp[col]
        data = pd.merge(data, tmp[['date_block_num', 'item_id', 'shop_id', col + '_lag_' + str(lag)]],
                       on=['date_block_num','shop_id','item_id'], how='left')
        data[col + '_lag_' + str(lag)] = data[col + '_lag_' + str(lag)].astype('float16')
    for lag in numbers:
        tmp = new_train[['date_block_num', 'item_id', 'shop_id', col]].copy()
        tmp = tmp.loc[tmp['date_block_num'] == 34-lag]
        tmp[col + '_lag_' + str(lag)] = tmp[col]
        test = pd.merge(test, tmp[['item_id', 'shop_id', col + '_lag_' + str(lag)]],
                       on=['shop_id','item_id'], how='left')
        test[col + '_lag_' + str(lag)] = test[col + '_lag_' + str(lag)].astype('float16')
    return data, test

# %% [markdown]
# #### item_cnt_day

# %%
new_train, test = create_lag(new_train, test, 'item_cnt_day', NUMBERS)

# %%
print(new_train.shape)
print(test.shape)
# Out:
# (10913850, 15)
# (214200, 14)

# %% [markdown]
# ### Creating aggregated columns and lags for them

# %%
def create_agg(data, by, agg_col, agg_method, new_col):
    tmp = data.groupby(by).agg({agg_col:agg_method})
    tmp[new_col] = tmp[agg_col]
    data = data.join(tmp, on=by, how='left', rsuffix='_out')
    data.drop(columns= agg_col + '_out', inplace=True)
    return data

# %% [markdown]
# #### Item month average lags

# %%
new_train = create_agg(new_train, ['item_id', 'date_block_num'], 'item_cnt_day', 'mean', 'item_month_avg')

# %%
new_train, test = create_lag(new_train, test, 'item_month_avg', NUMBERS)

# %%
new_train.drop(columns='item_month_avg', inplace=True)

# %% [markdown]
# #### City month average lags

# %%
new_train = create_agg(new_train, ['shop_city', 'date_block_num'], 'item_cnt_day', 'mean', 'city_month_avg')

# %%
new_train, test = create_lag(new_train, test, 'city_month_avg', NUMBERS)

# %%
new_train.drop(columns='city_month_avg', inplace=True)

# %% [markdown]
# #### Shop month average lags

# %%
new_train = create_agg(new_train, ['shop_id', 'date_block_num'], 'item_cnt_day', 'mean', 'shop_month_avg')

# %%
new_train, test = create_lag(new_train, test, 'shop_month_avg', NUMBERS)

# %%
new_train.drop(columns='shop_month_avg', inplace=True)

# %% [markdown]
# ### December (pick sales month) mark feature

# %%
new_train['pick_month'] = np.where(new_train['month'] == 11, 1, 0)
test['pick_month'] = 0

# %%
new_train.fillna(0, inplace=True)
test.fillna(0, inplace=True)

# %% [markdown]
# ### Trend features (diff)

# %% [markdown]
# **Last 5 months**

# %%
DIFF_NUMBERS = 5
def create_diff(data, test, col, numbers):
    for i in range(1, numbers+1):
        data[col + '_diff_' + str(i)] = data[col + '_lag_' + str(i+1)] - data[col + '_lag_' + str(i)]
        test[col + '_diff_' + str(i)] = test[col + '_lag_' + str(i+1)] - test[col + '_lag_' + str(i)]
    return data, test

# %%
new_train, test = create_diff(new_train, test, 'item_cnt_day', DIFF_NUMBERS)
new_train, test = create_diff(new_train, test, 'shop_month_avg', DIFF_NUMBERS)
new_train, test = create_diff(new_train, test, 'item_month_avg', DIFF_NUMBERS)
new_train, test = create_diff(new_train, test, 'city_month_avg', DIFF_NUMBERS)

# %%
fig, ax = pyplot.subplots(figsize=(20, 20))
sns.heatmap(new_train.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Creating dataset

# %%
new_train = new_train[new_train['date_block_num'] > 11]

# %%
encoder = LabelEncoder()
new_train['category'] = encoder.fit_transform(new_train['category'])
test['category'] = encoder.transform(test['category'])
new_train['shop_city'] = encoder.fit_transform(new_train['shop_city'])
test['shop_city'] = encoder.transform(test['shop_city'])
new_train['category'] = new_train['category'].astype('int16')
new_train['shop_city'] = new_train['shop_city'].astype('int16')
test['category'] = test['category'].astype('int16')
test['shop_city'] = test['shop_city'].astype('int16')
new_train['pick_month'] = new_train['pick_month'].astype('int8')
test['pick_month'] = test['pick_month'].astype('int8')

# %%
new_train.dtypes
# Out:
# date_block_num             int16
# shop_id                    int16
# item_cnt_day             float32
# item_id                    int16
# category                   int16
# month                      int16
# year                       int16
# shop_city                  int16
# item_cnt_day_lag_1       float16
# item_cnt_day_lag_2       float16
# item_cnt_day_lag_3       float16
# item_cnt_day_lag_4       float16
# item_cnt_day_lag_5       float16
# item_cnt_day_lag_6       float16
# item_cnt_day_lag_12      float16
# item_month_avg_lag_1     float16
# item_month_avg_lag_2     float16
# item_month_avg_lag_3     float16
# item_month_avg_lag_4     float16
# item_month_avg_lag_5     float16
# item_month_avg_lag_6     float16
# item_month_avg_lag_12    float16
# city_month_avg_lag_1     float16
# city_month_avg_lag_2     float16
# city_month_avg_lag_3     float16
# city_month_avg_lag_4     float16
# city_month_avg_lag_5     float16
# city_month_avg_lag_6     float16
# city_month_avg_lag_12    float16
# shop_month_avg_lag_1     float16
# shop_month_avg_lag_2     float16
# shop_month_avg_lag_3     float16
# shop_month_avg_lag_4     float16
# shop_month_avg_lag_5     float16
# shop_month_avg_lag_6     float16
# shop_month_avg_lag_12    float16
# pick_month                  int8
# item_cnt_day_diff_1      float16
# item_cnt_day_diff_2      float16
# item_cnt_day_diff_3      float16
# item_cnt_day_diff_4      float16
# item_cnt_day_diff_5      float16
# shop_month_avg_diff_1    float16
# shop_month_avg_diff_2    float16
# shop_month_avg_diff_3    float16
# shop_month_avg_diff_4    float16
# shop_month_avg_diff_5    float16
# item_month_avg_diff_1    float16
# item_month_avg_diff_2    float16
# item_month_avg_diff_3    float16
# item_month_avg_diff_4    float16
# item_month_avg_diff_5    float16
# city_month_avg_diff_1    float16
# city_month_avg_diff_2    float16
# city_month_avg_diff_3    float16
# city_month_avg_diff_4    float16
# city_month_avg_diff_5    float16
# dtype: object

# %%
X_train = new_train.loc[new_train['date_block_num'] < 33, :].drop(columns='item_cnt_day')
Y_train = new_train.loc[new_train['date_block_num'] < 33, 'item_cnt_day']

X_valid = new_train.loc[new_train['date_block_num'] == 33, :].drop(columns='item_cnt_day')
Y_valid = new_train.loc[new_train['date_block_num'] == 33, 'item_cnt_day']

X_train_test = new_train.drop(columns='item_cnt_day')
Y_train_test = new_train['item_cnt_day']

X_test = test.copy()

# %%
print(X_train.shape, Y_train.shape)
print(X_valid.shape, Y_valid.shape)
print(X_train_test.shape, Y_train_test.shape)
print(X_test.shape)
# Out:
# (6186922, 56) (6186922,)
# (238172, 56) (238172,)
# (6425094, 56) (6425094,)
# (214200, 56)

# %%
del new_train
del test

# %% [markdown]
# ### Building a model (LGBM)

# %%
train_data = lgb.Dataset(X_train, label=Y_train)
valid_data = lgb.Dataset(X_valid, label=Y_valid, reference=train_data)

# %%
evals_result = {}

# %%
params = {
    'objective':'regression',
    'random_state' : 22,
    'max_depth' : 7,
    'num_leaves': 100,
    'num_iterations' : 300,
    'verbosity' : 1,
    'min_data_in_leaf' : 50,
    'feature_fraction' : 1,
    'bagging_fraction' : 1,
    'bagging_freq': 5,
    'metric' : 'rmse',
    'early_stopping_round' : 15,
    'learning_rate' : 0.05,
}

cat_features = ['category', 'shop_city', 'pick_month']

# %%
model = lgb.train(params, train_data, valid_sets=[train_data, valid_data], verbose_eval=1, categorical_feature=cat_features, evals_result=evals_result)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1555: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['category', 'pick_month', 'shop_city']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.957776 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9905
# [LightGBM] [Info] Number of data points in the train set: 6186922, number of used features: 56
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Info] Start training from score 0.289434
# [1]	training's rmse: 1.16554	valid_1's rmse: 1.1207
# Training until validation scores don't improve for 15 rounds
# [2]	training's rmse: 1.14339	valid_1's rmse: 1.10527
# [3]	training's rmse: 1.12306	valid_1's rmse: 1.09123
# [4]	training's rmse: 1.10432	valid_1's rmse: 1.07841
# [5]	training's rmse: 1.08701	valid_1's rmse: 1.06658
# [6]	training's rmse: 1.07102	valid_1's rmse: 1.05581
# [7]	training's rmse: 1.05639	valid_1's rmse: 1.04614
# [8]	training's rmse: 1.04274	valid_1's rmse: 1.03713
# [9]	training's rmse: 1.0303	valid_1's rmse: 1.0292
# [10]	training's rmse: 1.01881	valid_1's rmse: 1.02192
# [11]	training's rmse: 1.00825	valid_1's rmse: 1.01526
# [12]	training's rmse: 0.998487	valid_1's rmse: 1.00918
# [13]	training's rmse: 0.989478	valid_1's rmse: 1.00349
# [14]	training's rmse: 0.981188	valid_1's rmse: 0.99854
# [15]	training's rmse: 0.973456	valid_1's rmse: 0.993714
# [16]	training's rmse: 0.96638	valid_1's rmse: 0.989526
# [17]	training's rmse: 0.959924	valid_1's rmse: 0.985266
# [18]	training's rmse: 0.953895	valid_1's rmse: 0.981752
# [19]	training's rmse: 0.948375	valid_1's rmse: 0.978439
# [20]	training's rmse: 0.94311	valid_1's rmse: 0.975437
# [21]	training's rmse: 0.93841	valid_1's rmse: 0.972631
# [22]	training's rmse: 0.933917	valid_1's rmse: 0.969879
# [23]	training's rmse: 0.929896	valid_1's rmse: 0.967793
# [24]	training's rmse: 0.926152	valid_1's rmse: 0.965736
# [25]	training's rmse: 0.92267	valid_1's rmse: 0.963823
# [26]	training's rmse: 0.919383	valid_1's rmse: 0.962058
# [27]	training's rmse: 0.916294	valid_1's rmse: 0.960389
# [28]	training's rmse: 0.91358	valid_1's rmse: 0.959046
# [29]	training's rmse: 0.91098	valid_1's rmse: 0.957665
# [30]	training's rmse: 0.908482	valid_1's rmse: 0.956498
# [31]	training's rmse: 0.906133	valid_1's rmse: 0.955534
# [32]	training's rmse: 0.903971	valid_1's rmse: 0.954526
# [33]	training's rmse: 0.902012	valid_1's rmse: 0.953497
# [34]	training's rmse: 0.900116	valid_1's rmse: 0.952632
# [35]	training's rmse: 0.898295	valid_1's rmse: 0.951838
# [36]	training's rmse: 0.896555	valid_1's rmse: 0.951122
# [37]	training's rmse: 0.894929	valid_1's rmse: 0.950409
# [38]	training's rmse: 0.893496	valid_1's rmse: 0.949848
# [39]	training's rmse: 0.892094	valid_1's rmse: 0.949282
# [40]	training's rmse: 0.890757	valid_1's rmse: 0.948831
# [41]	training's rmse: 0.889517	valid_1's rmse: 0.94834
# [42]	training's rmse: 0.888293	valid_1's rmse: 0.947789
# [43]	training's rmse: 0.887196	valid_1's rmse: 0.947323
# [44]	training's rmse: 0.886174	valid_1's rmse: 0.946859
# [45]	training's rmse: 0.885112	valid_1's rmse: 0.946442
# [46]	training's rmse: 0.884172	valid_1's rmse: 0.946173
# [47]	training's rmse: 0.883207	valid_1's rmse: 0.945834
# [48]	training's rmse: 0.882269	valid_1's rmse: 0.945549
# [49]	training's rmse: 0.881368	valid_1's rmse: 0.945131
# [50]	training's rmse: 0.880471	valid_1's rmse: 0.944915
# [51]	training's rmse: 0.879731	valid_1's rmse: 0.944653
# [52]	training's rmse: 0.878928	valid_1's rmse: 0.944454
# [53]	training's rmse: 0.878185	valid_1's rmse: 0.944198
# [54]	training's rmse: 0.877442	valid_1's rmse: 0.944002
# [55]	training's rmse: 0.876704	valid_1's rmse: 0.943861
# [56]	training's rmse: 0.87601	valid_1's rmse: 0.943534
# [57]	training's rmse: 0.875256	valid_1's rmse: 0.943183
# [58]	training's rmse: 0.874722	valid_1's rmse: 0.943084
# [59]	training's rmse: 0.874034	valid_1's rmse: 0.943018
# [60]	training's rmse: 0.873368	valid_1's rmse: 0.942813
# [61]	training's rmse: 0.872763	valid_1's rmse: 0.94245
# [62]	training's rmse: 0.872234	valid_1's rmse: 0.942237
# [63]	training's rmse: 0.871692	valid_1's rmse: 0.942046
# [64]	training's rmse: 0.871139	valid_1's rmse: 0.941885
# [65]	training's rmse: 0.870595	valid_1's rmse: 0.941857
# [66]	training's rmse: 0.870059	valid_1's rmse: 0.941685
# [67]	training's rmse: 0.869551	valid_1's rmse: 0.941394
# [68]	training's rmse: 0.869044	valid_1's rmse: 0.941222
# [69]	training's rmse: 0.868562	valid_1's rmse: 0.941187
# [70]	training's rmse: 0.867983	valid_1's rmse: 0.941069
# [71]	training's rmse: 0.867544	valid_1's rmse: 0.941045
# [72]	training's rmse: 0.867126	valid_1's rmse: 0.941006
# [73]	training's rmse: 0.866593	valid_1's rmse: 0.940957
# [74]	training's rmse: 0.866195	valid_1's rmse: 0.940812
# [75]	training's rmse: 0.865745	valid_1's rmse: 0.940771
# [76]	training's rmse: 0.865363	valid_1's rmse: 0.940699
# [77]	training's rmse: 0.865027	valid_1's rmse: 0.940712
# [78]	training's rmse: 0.864698	valid_1's rmse: 0.940639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	training's rmse: 0.864369	valid_1's rmse: 0.940521
# [80]	training's rmse: 0.863968	valid_1's rmse: 0.94054
# [81]	training's rmse: 0.863656	valid_1's rmse: 0.940409
# [82]	training's rmse: 0.863344	valid_1's rmse: 0.940389
# [83]	training's rmse: 0.863055	valid_1's rmse: 0.940374
# [84]	training's rmse: 0.862795	valid_1's rmse: 0.940219
# [85]	training's rmse: 0.862521	valid_1's rmse: 0.940171
# [86]	training's rmse: 0.862228	valid_1's rmse: 0.94004
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	training's rmse: 0.861954	valid_1's rmse: 0.940011
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	training's rmse: 0.861668	valid_1's rmse: 0.939923
# [89]	training's rmse: 0.861288	valid_1's rmse: 0.939989
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	training's rmse: 0.860954	valid_1's rmse: 0.939876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	training's rmse: 0.860703	valid_1's rmse: 0.939769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	training's rmse: 0.860432	valid_1's rmse: 0.939864
# [93]	training's rmse: 0.860175	valid_1's rmse: 0.939826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	training's rmse: 0.859893	valid_1's rmse: 0.939712
# [95]	training's rmse: 0.859639	valid_1's rmse: 0.939544
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	training's rmse: 0.859443	valid_1's rmse: 0.93951
# [97]	training's rmse: 0.859221	valid_1's rmse: 0.939466
# [98]	training's rmse: 0.858941	valid_1's rmse: 0.939426
# [99]	training's rmse: 0.858738	valid_1's rmse: 0.939461
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	training's rmse: 0.858516	valid_1's rmse: 0.939498
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	training's rmse: 0.858299	valid_1's rmse: 0.939595
# [102]	training's rmse: 0.857999	valid_1's rmse: 0.939506
# [103]	training's rmse: 0.857795	valid_1's rmse: 0.939347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	training's rmse: 0.857576	valid_1's rmse: 0.939307
# [105]	training's rmse: 0.857213	valid_1's rmse: 0.939268
# [106]	training's rmse: 0.857047	valid_1's rmse: 0.939215
# [107]	training's rmse: 0.856854	valid_1's rmse: 0.939122
# [108]	training's rmse: 0.856613	valid_1's rmse: 0.939113
# [109]	training's rmse: 0.856328	valid_1's rmse: 0.938885
# [110]	training's rmse: 0.855839	valid_1's rmse: 0.939134
# [111]	training's rmse: 0.855656	valid_1's rmse: 0.939062
# [112]	training's rmse: 0.855351	valid_1's rmse: 0.93872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	training's rmse: 0.855208	valid_1's rmse: 0.938598
# [114]	training's rmse: 0.854953	valid_1's rmse: 0.938582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	training's rmse: 0.854519	valid_1's rmse: 0.938259
# [116]	training's rmse: 0.854256	valid_1's rmse: 0.938183
# [117]	training's rmse: 0.854072	valid_1's rmse: 0.938279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	training's rmse: 0.853898	valid_1's rmse: 0.938232
# [119]	training's rmse: 0.853705	valid_1's rmse: 0.938222
# [120]	training's rmse: 0.85329	valid_1's rmse: 0.937901
# [121]	training's rmse: 0.853026	valid_1's rmse: 0.93758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	training's rmse: 0.852898	valid_1's rmse: 0.937559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	training's rmse: 0.852711	valid_1's rmse: 0.937534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	training's rmse: 0.852526	valid_1's rmse: 0.937608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	training's rmse: 0.852342	valid_1's rmse: 0.937519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	training's rmse: 0.85222	valid_1's rmse: 0.937656
# [127]	training's rmse: 0.852059	valid_1's rmse: 0.937659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	training's rmse: 0.851929	valid_1's rmse: 0.937725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	training's rmse: 0.851691	valid_1's rmse: 0.937532
# [130]	training's rmse: 0.851498	valid_1's rmse: 0.93761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	training's rmse: 0.851299	valid_1's rmse: 0.937604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	training's rmse: 0.850955	valid_1's rmse: 0.937458
# [133]	training's rmse: 0.850516	valid_1's rmse: 0.937371
# [134]	training's rmse: 0.850364	valid_1's rmse: 0.937414
# [135]	training's rmse: 0.850188	valid_1's rmse: 0.937386
# [136]	training's rmse: 0.850004	valid_1's rmse: 0.937331
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	training's rmse: 0.849886	valid_1's rmse: 0.93735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	training's rmse: 0.849552	valid_1's rmse: 0.937354
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	training's rmse: 0.84942	valid_1's rmse: 0.937341
# [140]	training's rmse: 0.849257	valid_1's rmse: 0.937304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	training's rmse: 0.849017	valid_1's rmse: 0.937242
# [142]	training's rmse: 0.848633	valid_1's rmse: 0.936269
# [143]	training's rmse: 0.848434	valid_1's rmse: 0.936203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	training's rmse: 0.848292	valid_1's rmse: 0.936261
# [145]	training's rmse: 0.848113	valid_1's rmse: 0.936253
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	training's rmse: 0.847855	valid_1's rmse: 0.936301
# [147]	training's rmse: 0.847647	valid_1's rmse: 0.936218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	training's rmse: 0.847463	valid_1's rmse: 0.936145
# [149]	training's rmse: 0.847326	valid_1's rmse: 0.936112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	training's rmse: 0.847116	valid_1's rmse: 0.935923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	training's rmse: 0.846905	valid_1's rmse: 0.935844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	training's rmse: 0.846777	valid_1's rmse: 0.935805
# [153]	training's rmse: 0.846578	valid_1's rmse: 0.935736
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	training's rmse: 0.846448	valid_1's rmse: 0.935761
# [155]	training's rmse: 0.8462	valid_1's rmse: 0.935655
# [156]	training's rmse: 0.84598	valid_1's rmse: 0.935827
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	training's rmse: 0.84582	valid_1's rmse: 0.935822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	training's rmse: 0.845693	valid_1's rmse: 0.935794
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	training's rmse: 0.845603	valid_1's rmse: 0.935727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	training's rmse: 0.845443	valid_1's rmse: 0.935624
# [161]	training's rmse: 0.845248	valid_1's rmse: 0.935539
# [162]	training's rmse: 0.845013	valid_1's rmse: 0.935279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	training's rmse: 0.844829	valid_1's rmse: 0.935399
# [164]	training's rmse: 0.844646	valid_1's rmse: 0.935434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	training's rmse: 0.84447	valid_1's rmse: 0.935596
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	training's rmse: 0.8443	valid_1's rmse: 0.935526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	training's rmse: 0.844214	valid_1's rmse: 0.935486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	training's rmse: 0.843932	valid_1's rmse: 0.935417
# [169]	training's rmse: 0.84376	valid_1's rmse: 0.935427
# [170]	training's rmse: 0.843621	valid_1's rmse: 0.935375
# [171]	training's rmse: 0.843371	valid_1's rmse: 0.935363
# [172]	training's rmse: 0.843112	valid_1's rmse: 0.935233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	training's rmse: 0.843011	valid_1's rmse: 0.935196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	training's rmse: 0.842887	valid_1's rmse: 0.935215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	training's rmse: 0.842732	valid_1's rmse: 0.935252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	training's rmse: 0.84261	valid_1's rmse: 0.935233
# [177]	training's rmse: 0.842422	valid_1's rmse: 0.935271
# [178]	training's rmse: 0.842194	valid_1's rmse: 0.935165
# [179]	training's rmse: 0.842025	valid_1's rmse: 0.93512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	training's rmse: 0.841974	valid_1's rmse: 0.935087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	training's rmse: 0.841819	valid_1's rmse: 0.934939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	training's rmse: 0.841601	valid_1's rmse: 0.934878
# [183]	training's rmse: 0.841387	valid_1's rmse: 0.93481
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	training's rmse: 0.841262	valid_1's rmse: 0.934815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	training's rmse: 0.841112	valid_1's rmse: 0.934788
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	training's rmse: 0.841036	valid_1's rmse: 0.934904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	training's rmse: 0.840899	valid_1's rmse: 0.934885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	training's rmse: 0.840794	valid_1's rmse: 0.934877
# [189]	training's rmse: 0.840638	valid_1's rmse: 0.934923
# [190]	training's rmse: 0.840443	valid_1's rmse: 0.934683
# [191]	training's rmse: 0.840304	valid_1's rmse: 0.93473
# [192]	training's rmse: 0.840216	valid_1's rmse: 0.934741
# [193]	training's rmse: 0.840093	valid_1's rmse: 0.934822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	training's rmse: 0.840012	valid_1's rmse: 0.934895
# [195]	training's rmse: 0.839833	valid_1's rmse: 0.934859
# [196]	training's rmse: 0.839736	valid_1's rmse: 0.93481
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	training's rmse: 0.83962	valid_1's rmse: 0.934811
# [198]	training's rmse: 0.839449	valid_1's rmse: 0.934927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	training's rmse: 0.839332	valid_1's rmse: 0.935181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	training's rmse: 0.83921	valid_1's rmse: 0.93521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	training's rmse: 0.839043	valid_1's rmse: 0.935135
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	training's rmse: 0.838916	valid_1's rmse: 0.935046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	training's rmse: 0.838801	valid_1's rmse: 0.935035
# [204]	training's rmse: 0.838683	valid_1's rmse: 0.934996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	training's rmse: 0.838595	valid_1's rmse: 0.934978
# Early stopping, best iteration is:
# [190]	training's rmse: 0.840443	valid_1's rmse: 0.934683

# %%
import matplotlib.pyplot as plt
ax = lgb.plot_metric(evals_result)
plt.show()

# %%
from lightgbm import plot_importance
import matplotlib.pyplot as plt

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

plot_features(model, (10,14))
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
params = {
    'objective':'regression',
    'random_state' : 22,
    'max_depth' : 7,
    'num_leaves': 100,
    'num_iterations' : 190,
    'verbosity' : 1,
    'min_data_in_leaf' : 50,
    'feature_fraction' : 1,
    'bagging_fraction' : 1,
    'bagging_freq': 5,
    'metric' : 'rmse',
    'learning_rate' : 0.05,
}

cat_features = ['category', 'shop_city', 'pick_month']

# %%
train_data = lgb.Dataset(X_train_test, label=Y_train_test)

# %%
LGBM_model = lgb.train(params, train_data, verbose_eval=1, categorical_feature=cat_features)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.877627 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 9907
# [LightGBM] [Info] Number of data points in the train set: 6425094, number of used features: 56
# [LightGBM] [Info] Start training from score 0.288308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
LGBM_y = LGBM_model.predict(X_test)

# %%
Y = 0.7*LGBM_y + 0.15*LSTM_y + 0.15*GRU_y

# %%
print(LGBM_y[:10])
print(LSTM_y[:10])
print(GRU_y[:10])
print(Y[:10])
# Out:
# [0.47177371 0.139845   0.83594653 0.32445688 0.139845   0.46741391
#  0.66912627 0.15084808 1.0253546  1.0342286 ]
# [0.53421605 0.10584176 0.83468235 0.1600312  0.10584176 0.48627037
#  0.9866969  0.14854145 1.1454602  0.10584176]
# [0.56328404 0.1205346  0.8654703  0.19189286 0.1205346  0.52439827
#  0.9096911  0.18838805 1.0987042  0.1205346 ]
# [0.49486661 0.13184795 0.84018549 0.27990843 0.13184795 0.47879004
#  0.75284661 0.15613308 1.0543729  0.75791647]

# %%
sample = pd.read_csv(r'../input/competitive-data-science-predict-future-sales/sample_submission.csv')
sample['item_cnt_month'] = LGBM_y
sample.to_csv(path_or_buf=r'./submission_LGBM.csv', index=False)
sample['item_cnt_month'] = LSTM_y
sample.to_csv(path_or_buf=r'./submission_LSTM.csv', index=False)
sample['item_cnt_month'] = GRU_y
sample.to_csv(path_or_buf=r'./submission_GRU.csv', index=False)
sample['item_cnt_month'] = Y
sample.to_csv(path_or_buf=r'./submission_Ensamble.csv', index=False)
